# %%
# 1. Import libraries
import pandas as pd
import os, sys
sys.path.append('../4_Source_Code')

# %%
# 2. Load dataset
DATA='../1_Data/AI_Car_Recommendation_Safety_5000.csv'
df=pd.read_csv(DATA)
print(df.shape)
df.head()

# %%
# 3. Explore dataset
print(df.info())
print(df.isnull().sum())
print('Duplicates:', df.duplicated().sum())

# %%
# 4. Train all models
exec(open('../4_Source_Code/train_models.py', encoding='utf-8').read())

# %%
# 5. Check saved models
import os
print(os.listdir('../3_Models'))
